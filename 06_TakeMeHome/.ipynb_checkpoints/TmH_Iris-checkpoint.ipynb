# %% [markdown]
# ## Take Me Home Challenge: Iris
#
# Der Blumenhändler "Iris blüht" möchte die Iris Sorten (Schwertlilien) Setosa, Versicolor und Virginica vertreiben. Leider hat er derzeit wenig Kenntnis über die Blumen. Er hat jedoch sich Bilder ausgeben lassen:
#
# | **Setosa** | **Versicolor** | **Virginica** |
# | --- | --- | ---|
# |![title](iris_setosa.jpg) | ![title](iris_versicolor.jpg)| ![title](iris_virginica.jpg)
#
#
# Er erkennt nur, dass alle Iris Sorten lila sind. Nun hat er von einem Konkurrenten freundlicherweise eine Liste erhalten, über seine Verkauften Iris Sorten letztes Jahr im Mai. Mit dieser Liste kommt er nun zu Ihnen.
#
# <br>
# <br>
# Die Liste enthält folgende Informationen:
# <br>
#
# | Name | Beschreibung |
# |---|---|
# | Sepal Length | Länge der Kelchblätter |
# | Sepal Width | Breite der Kelchblätter |
# | Pedal Length | Länge der Blütenblätter |
# | Pedal Width | Breite der Blütenblätter |
# | Ort | einstellige Ziffern |
# | Anzahl | Verkaufte Stückzahl |
#
# <br>
# <br>
# Nach längerem Bitten erhält er auch noch die Informationen, welche Ortschaften sich hinter den Ziffern befinden:
# <br>
#
# | Zahl | Ort |
# | --- | --- |
# | 0 | München |
# | 1 | Rostock |
# | 2 | Trier |
# | 3 | Münster |
# | 4 | Ulm |
# | 5 | Hamburg |
# | 6 | Köln |
# | 7 | Würzburg |
# | 8 | Leipzig |
# | 9 | Wolfsburg |
#
# <br>
# <br>
# Desweiteren möchte der Blumenhändler seinen Verkaufspreis anhand der Länge der Blütenblätter festlegen, da er meint, dass dies das entscheidende Qualitätskriterium ist.
# <br>
#
#
# | Petal Width in CM | Preis pro Stück |
# | --- | --- |
# | PW < 1 | 2.55 |
# | 1 <= PW < 2 | 2.66 |
# | 2 <= PW < 3 | 2.68 |
# | 3 <= PW < 4 | 2.72 |
# | 4 <= PW < 5 | 2.77 |
# | 5 <= PW < 6 | 2.85 |
# | 6 <= PW < 7 | 2.90 |
# | 7 <= PW  | 3.00 |
#
# <br>
# <br>
#
# Da der Blümenhändler eifrig sein möchte, möchte er auch die Planzen selber züchten. Er rechnet mit folgenden Kosten:
#
# | Sorte | Kosten pro Stück |
# | --- | --- |
# | Setosa | 1.03 |
# | Versicolor | 0.98 |
# | Virginica | 1.55 |

# %% [markdown]
# ### Aufgabe
#
# 1. Ersetzen Sie die Zahlen mit den jeweiligen Orte.
# 2. Der Blumenhändler hat schon festgestellt, dass ein paar Informationen über die Kelchblätter fehlen. Er möchte nicht, dass diese Elemente gelöscht werden, sondern durch den jeweiligen Median ersetzt werden. (Hinweis: Ausreißer sind ansonsten hier nicht zu erwarten.)
# 3. Informieren Sie den Blumenhändler, wie sich die Irise unterscheiden.
# 4. Visualisieren Sie, ob die Merkmale der Kelch- und Blütenblätter korrelieren.
# 5. Bestimmen Sie rechnerisch, wie auch visuell, welche Sorte, die Häufigkeit und an welchem Ort verkauft wurde.
#
# #### Zusatz 1
# 6. Ermitteln Sie den Preis, Kosten und Gewinn je Sorte.
# 7. Ermitteln Sie den Gewinn an den jeweiligen Standorten pro Sorte.
# 8. Können Sie eine Empfehlung für die Zucht und Verkauf den Blumenhändler anbieten?
#
#
# <font color='purple'>**Kommentare und Präsentation sind wichtiger, als alle Aufgaben zu lösen!**</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("iris_final.csv")

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df
# Out:
#               Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0         Iris-setosa       4.959947      3.210710       1.673597
# 1         Iris-setosa       4.777595      3.131878       1.413592
# 2         Iris-setosa       4.807163      3.475521       1.371495
# 3         Iris-setosa       4.752104      3.738200       1.435881
# 4         Iris-setosa       5.021368      2.382476       1.257389
# ...               ...            ...           ...            ...
# 33328  Iris-virginica       6.845773      3.168164       5.296417
# 33329  Iris-virginica       6.129696      2.630707       6.176997
# 33330  Iris-virginica       6.191558      2.812238       6.362977
# 33331  Iris-virginica       5.275439      2.425751       6.293001
# 33332  Iris-virginica       6.161632      2.707732       5.950846
#
#        PetalWidthCm  Ort  Anzahl
# 0          0.248389    4     172
# 1          0.113217    2     138
# 2          0.159915    0     144
# 3          0.234247    1     210
# ...

# %%
df.Anzahl.sum()
# Out:
# 4996851

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm           Ort  \
# count   33258.000000  33266.000000   33251.000000  33257.000000  33333.000000
# mean        5.842875      3.051325       3.759283      1.198384      4.496025
# std         0.827478      0.433171       1.759673      0.762313      2.873815
# min         3.497633      1.480765       0.866959     -0.154528      0.000000
# 25%         5.162826      2.743533       1.578923      0.315163      2.000000
# 50%         5.815321      3.020141       4.253168      1.322284      4.000000
# 75%         6.445396      3.338377       5.214180      1.844181      7.000000
# max         9.178336      4.997633       7.941772      3.018332      9.000000
#
#              Anzahl
# count  33333.000000
# mean     149.907029
# std       86.454007
# min        1.000000
# 25%       75.000000
# 50%      150.000000
# 75%      225.000000
# max      299.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33333 entries, 0 to 33332
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        33333 non-null  object
#  1   SepalLengthCm  33258 non-null  float64
#  2   SepalWidthCm   33266 non-null  float64
#  3   PetalLengthCm  33251 non-null  float64
#  4   PetalWidthCm   33257 non-null  float64
#  5   Ort            33333 non-null  int64
#  6   Anzahl         33333 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
df.Species.unique()
#list(df.columns.values)[1:5]
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
for specie in list(df.Species.unique()):
    for size in list(df.columns.values)[1:5]:
        m = df.loc[df["Species"] == specie, size].mean()
        df.loc[(df["Species"] == specie) & (df[size].isnull()), size] = m

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33333 entries, 0 to 33332
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        33333 non-null  object
#  1   SepalLengthCm  33333 non-null  float64
#  2   SepalWidthCm   33333 non-null  float64
#  3   PetalLengthCm  33333 non-null  float64
#  4   PetalWidthCm   33333 non-null  float64
#  5   Ort            33333 non-null  int64
#  6   Anzahl         33333 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
df
# Out:
#               Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0         Iris-setosa       4.959947      3.210710       1.673597
# 1         Iris-setosa       4.777595      3.131878       1.413592
# 2         Iris-setosa       4.807163      3.475521       1.371495
# 3         Iris-setosa       4.752104      3.738200       1.435881
# 4         Iris-setosa       5.021368      2.382476       1.257389
# ...               ...            ...           ...            ...
# 33328  Iris-virginica       6.845773      3.168164       5.296417
# 33329  Iris-virginica       6.129696      2.630707       6.176997
# 33330  Iris-virginica       6.191558      2.812238       6.362977
# 33331  Iris-virginica       5.275439      2.425751       6.293001
# 33332  Iris-virginica       6.161632      2.707732       5.950846
#
#        PetalWidthCm  Ort  Anzahl
# 0          0.248389    4     172
# 1          0.113217    2     138
# 2          0.159915    0     144
# 3          0.234247    1     210
# ...

# %%
def set_ort(n):
    orte = ["München", "Rostock", "Trier", "Münster", "Ulm", "Hamburg", "Köln", "Würzburg", "Leipzig", "Wolfsburg"]
    return orte[n]

df["Ort"] = df["Ort"].apply(set_ort)
df["Ort"]
# Out:
# 0              Ulm
# 1            Trier
# 2          München
# 3          Rostock
# 4          Hamburg
#            ...
# 33328        Trier
# 33329    Wolfsburg
# 33330         Köln
# 33331      Rostock
# 33332      Rostock
# Name: Ort, Length: 33333, dtype: object

# %%
pd.pivot_table(df, index="Species", values=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"], aggfunc="mean")
# Out:
#                  PetalLengthCm  PetalWidthCm  SepalLengthCm  SepalWidthCm
# Species
# Iris-setosa           1.462656      0.242776       5.001557      3.413659
# Iris-versicolor       4.265375      1.324537       5.944046      2.770759
# Iris-virginica        5.549980      2.027374       6.581540      2.969488

# %%
pd.pivot_table(df, index="Species", values="Anzahl", columns="Ort", aggfunc="sum", margins=True)
# Out:
# Ort              Hamburg    Köln  Leipzig  München  Münster  Rostock   Trier  \
# Species
# Iris-setosa       167788  159494   167592   165719   167454   163644  169915
# Iris-versicolor   166659  176075   168419   169350   170506   171531  158372
# Iris-virginica    172349  157197   166887   157590   171369   172741  164077
# All               506796  492766   502898   492659   509329   507916  492364
#
# Ort                 Ulm  Wolfsburg  Würzburg      All
# Species
# Iris-setosa      162176     172330    164970  1661082
# Iris-versicolor  158019     174757    167027  1680715
# Iris-virginica   177541     156555    158748  1655054
# All              497736     503642    490745  4996851

# %%
df1 = df.loc[df["Species"] == "Iris-setosa"].drop(["Anzahl"], axis=1)
df2 = df.loc[df["Species"] == "Iris-versicolor"].drop(["Anzahl"], axis=1)
df3 = df.loc[df["Species"] == "Iris-virginica"].drop(["Anzahl"], axis=1)

# %%
#sns.lineplot(data=df1, x="PetalLengthCm", y="PetalWidthCm")
sns.pairplot(df, hue="Species", vars=["PetalLengthCm", "PetalWidthCm"])

# %%
sns.pairplot(df, hue="Species", vars=["PetalLengthCm", "SepalLengthCm"])

# %%
df
# Out:
#               Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0         Iris-setosa       4.959947      3.210710       1.673597
# 1         Iris-setosa       4.777595      3.131878       1.413592
# 2         Iris-setosa       4.807163      3.475521       1.371495
# 3         Iris-setosa       4.752104      3.738200       1.435881
# 4         Iris-setosa       5.021368      2.382476       1.257389
# ...               ...            ...           ...            ...
# 33328  Iris-virginica       6.845773      3.168164       5.296417
# 33329  Iris-virginica       6.129696      2.630707       6.176997
# 33330  Iris-virginica       6.191558      2.812238       6.362977
# 33331  Iris-virginica       5.275439      2.425751       6.293001
# 33332  Iris-virginica       6.161632      2.707732       5.950846
#
#        PetalWidthCm        Ort  Anzahl
# 0          0.248389        Ulm     172
# 1          0.113217      Trier     138
# 2          0.159915    München     144
# ...

# %% [markdown]
# <br>
#
#
# | Petal Length in CM | Preis pro Stück |
# | --- | --- |
# | PW < 1 | 2.55 |
# | 1 <= PW < 2 | 2.66 |
# | 2 <= PW < 3 | 2.68 |
# | 3 <= PW < 4 | 2.72 |
# | 4 <= PW < 5 | 2.77 |
# | 5 <= PW < 6 | 2.85 |
# | 6 <= PW < 7 | 2.90 |
# | 7 <= PW  | 3.00 |
#
# <br>

# %%
df = df.drop(["SepalLengthCm", "SepalWidthCm", "PetalWidthCm"], axis=1)

# %%
def set_price(pl):
    if pl < 1: return 2.55
    elif 1<= pl < 2: return 2.66
    elif 2<= pl < 3: return 2.68
    elif 3<= pl < 4: return 2.72
    elif 4<= pl < 5: return 2.77
    elif 5<= pl < 6: return 2.85
    elif 6<= pl < 7: return 2.9
    else: return 3
    
def set_cost(specie):
    if specie == "Iris-setosa": return 1.03
    elif specie == "Iris-versicolor": return 0.98
    else: return 1.55

df["Price"] = df["PetalLengthCm"].apply(set_price)
df["Cost"] = df["Species"].apply(set_cost)
df["Profit"] = df["Anzahl"] * (df["Price"] - df["Cost"])
df
# Out:
#               Species  PetalLengthCm        Ort  Anzahl  Price  Cost  Profit
# 0         Iris-setosa       1.673597        Ulm     172   2.66  1.03  280.36
# 1         Iris-setosa       1.413592      Trier     138   2.66  1.03  224.94
# 2         Iris-setosa       1.371495    München     144   2.66  1.03  234.72
# 3         Iris-setosa       1.435881    Rostock     210   2.66  1.03  342.30
# 4         Iris-setosa       1.257389    Hamburg      72   2.66  1.03  117.36
# ...               ...            ...        ...     ...    ...   ...     ...
# 33328  Iris-virginica       5.296417      Trier     122   2.85  1.55  158.60
# 33329  Iris-virginica       6.176997  Wolfsburg     291   2.90  1.55  392.85
# 33330  Iris-virginica       6.362977       Köln     169   2.90  1.55  228.15
# 33331  Iris-virginica       6.293001    Rostock     110   2.90  1.55  148.50
# 33332  Iris-virginica       5.950846    Rostock     191   2.85  1.55  248.30
#
# [33333 rows x 7 columns]

# %%
pd.pivot_table(df, index="Species", values=["Price", "Cost", "Profit", "Anzahl"], aggfunc="mean")
# Out:
#                      Anzahl  Cost     Price      Profit
# Species
# Iris-setosa      149.498875  1.03  2.659704  243.635338
# Iris-versicolor  151.265863  0.98  2.760220  269.326469
# Iris-virginica   148.956350  1.55  2.847862  193.272872

# %%
pt = pd.pivot_table(df, index="Species", values="Profit", columns="Ort", aggfunc="mean")
pt
# Out:
# Ort                 Hamburg        Köln     Leipzig     München     Münster  \
# Species
# Iris-setosa      245.646855  238.443881  244.517699  240.277100  243.040276
# Iris-versicolor  268.061445  276.584793  268.361691  265.867822  269.423469
# Iris-virginica   196.698347  190.235808  194.218680  190.422954  193.952134
#
# Ort                 Rostock       Trier         Ulm   Wolfsburg    Würzburg
# Species
# Iris-setosa      245.344830  244.771627  245.653866  242.981462  245.753958
# Iris-versicolor  273.341620  261.711578  265.861870  274.115621  269.342545
# Iris-virginica   197.933304  189.945031  194.826644  190.380824  193.543515

# %%
pt.mean().sort_values(ascending=False)
# Out:
# Ort
# Rostock      238.873251
# Hamburg      236.802216
# Würzburg     236.213339
# Wolfsburg    235.825969
# Leipzig      235.699357
# Münster      235.471960
# Ulm          235.447460
# Köln         235.088160
# München      232.189292
# Trier        232.142746
# dtype: float64

# %%
pt.max().sort_values(ascending=False)
# Out:
# Ort
# Köln         276.584793
# Wolfsburg    274.115621
# Rostock      273.341620
# Münster      269.423469
# Würzburg     269.342545
# Leipzig      268.361691
# Hamburg      268.061445
# München      265.867822
# Ulm          265.861870
# Trier        261.711578
# dtype: float64

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(x="Ort", y="Profit", col="Species", data=df, kind="box")
chart.set_xticklabels(rotation=45, horizontalalignment='right')
