# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

np.random.seed(42)

# %%
data = pd.read_csv('iris_big.csv')
data.head()
# Out:
#    Unnamed: 0      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0           0  Iris-setosa       4.959947      3.210710       1.673597
# 1           1  Iris-setosa       4.777595      3.131878       1.413592
# 2           2  Iris-setosa       4.807163      3.475521       1.371495
# 3           3  Iris-setosa       4.752104      3.738200       1.435881
# 4           4  Iris-setosa       5.021368      2.382476       1.257389
#
#    PetalWidthCm
# 0      0.248389
# 1      0.113217
# 2      0.159915
# 3      0.234247
# 4      0.198184

# %%
data = data [['Species', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   33333.000000  33333.000000   33333.000000  33333.000000
# mean        5.842296      3.051284       3.759536      1.198300
# std         0.827460      0.433092       1.759817      0.762284
# min         3.497633      1.480765       0.866959     -0.154528
# 25%         5.162015      2.743464       1.578895      0.315163
# 50%         5.814593      3.020068       4.254307      1.322207
# 75%         6.444837      3.338166       5.214973      1.844141
# max         9.178336      4.997633       7.941772      3.018332

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33333 entries, 0 to 33332
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        33333 non-null  object
#  1   SepalLengthCm  33333 non-null  float64
#  2   SepalWidthCm   33333 non-null  float64
#  3   PetalLengthCm  33333 non-null  float64
#  4   PetalWidthCm   33333 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.3+ MB

# %%
data.groupby('Species').count()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              11111         11111          11111         11111
# Iris-versicolor          11111         11111          11111         11111
# Iris-virginica           11111         11111          11111         11111

# %%
#np.random.randint(0, 10, 33333)

# %%
data['Ort'] = [i for i in np.random.randint(0, 10, 33333)]
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Ort
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389    6
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217    3
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915    7
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247    4
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184    6

# %%
data['Anzahl'] = [i for i in np.random.randint(1, 300, 33333)]
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Ort  \
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389    6
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217    3
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915    7
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247    4
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184    6
#
#    Anzahl
# 0     157
# 1      22
# 2     126
# 3     169
# 4     166

# %%
# function to create some NaN's in the df
def create_nan(df, n):
    
    ''' Input: df - DataFrame
               n - number of NaNs
               
        Output: df - DataFrame
        
        This function creates a DataFrame including some NaN values.
        
        '''
    
    np.random.seed(3)
    
    for i in range(n):
        row_ind = np.random.randint(0, df.shape[0]) # 'high' exclusive!
        col_ind = np.random.randint(1, df.shape[1]-2)   # nicht Species und Ort und Anzahl
        
        df.iloc[row_ind,col_ind] = np.nan    # replace np.nan in df
        
    return df

# %%
# build a df with NaN by using function create_nan()
data = create_nan(data, 300)
data;

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33333 entries, 0 to 33332
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        33333 non-null  object
#  1   SepalLengthCm  33258 non-null  float64
#  2   SepalWidthCm   33266 non-null  float64
#  3   PetalLengthCm  33251 non-null  float64
#  4   PetalWidthCm   33257 non-null  float64
#  5   Ort            33333 non-null  int64
#  6   Anzahl         33333 non-null  int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
data['SepalLengthCM'] = [median:Setosa if i == 'Setosa' else median: Virgina if i = 'Virgina'... 
                        for i in data.Species]

# %%
np.median(data['SepalLengthCm'])
# Out:
# nan

# %%
data.SepalLengthCm.sort_values()
# Out:
# 1119     3.497633
# 8176     3.681268
# 1278     3.727983
# 8831     3.768881
# 5740     3.788110
#            ...
# 27993         NaN
# 31279         NaN
# 31367         NaN
# 32233         NaN
# 32736         NaN
# Name: SepalLengthCm, Length: 33333, dtype: float64

# %%
data[np.isnan(data.SepalLengthCm) == True]
# Out:
#               Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 44        Iris-setosa            NaN      3.647520       1.555325
# 363       Iris-setosa            NaN      3.882067       1.725425
# 1408      Iris-setosa            NaN      3.368570       1.527542
# 1565      Iris-setosa            NaN      3.459675       1.209189
# 1973      Iris-setosa            NaN      2.919493       1.540415
# ...               ...            ...           ...            ...
# 27993  Iris-virginica            NaN      2.993437       4.867378
# 31279  Iris-virginica            NaN      3.329912       5.282322
# 31367  Iris-virginica            NaN      2.680034       6.130273
# 32233  Iris-virginica            NaN      3.199363       4.745835
# 32736  Iris-virginica            NaN      2.634692       6.121709
#
#        PetalWidthCm  Ort  Anzahl
# 44         0.186717    9     153
# 363        0.515346    5      83
# 1408       0.341999    2      96
# 1565       0.198957    3      49
# ...

# %%
data.to_csv('iris_final.csv')

# %%
data.groupby('Species').max().T
# Out:
# Species             Iris-setosa Iris-versicolor Iris-virginica
# SepalLengthCm          6.435632        7.688034       9.178336
# SepalWidthCm           4.997633        3.957703        4.14198
# PetalLengthCm          2.176584        6.432384       7.941772
# PetalWidthCm           0.627741        2.029872       3.018332
# Ort                   Wuerzburg       Wuerzburg      Wuerzburg
# Anzahl                      299             299            299
# Preis                      2.83            2.83           2.83
# Zuechtung                  1.03            0.98           1.55
# Gewinn_pro_Stueck           1.8            1.85           1.28
# Gewinne_pro_Verkauf       1.854           1.813          1.984

# %%
data.groupby('Ort').count()
# Out:
#      Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Anzahl
# Ort
# 0       3331           3323          3326           3322          3327    3331
# 1       3336           3327          3332           3325          3325    3336
# 2       3329           3314          3324           3323          3323    3329
# 3       3398           3392          3396           3388          3387    3398
# 4       3318           3307          3313           3310          3312    3318
# 5       3357           3350          3343           3341          3349    3357
# 6       3294           3288          3285           3292          3289    3294
# 7       3262           3259          3254           3256          3252    3262
# 8       3349           3344          3339           3342          3340    3349
# 9       3359           3354          3354           3352          3353    3359

# %%
data['Ort'] = ['Muenchen' if i == 0 
               else 'Rostock' if i == 1 
               else 'Trier' if i == 2
               else 'Muenster' if i == 3
               else 'Ulm' if i == 4
               else 'Hamburg' if i == 5
               else 'Koeln' if i == 6
               else 'Wuerzburg' if i == 7
               else 'Leipzig' if i == 8
               else 'Wolfsburg' for i in data.Ort]
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184
#
#         Ort  Anzahl
# 0       Ulm     172
# 1     Trier     138
# 2  Muenchen     144
# 3   Rostock     210
# 4   Hamburg      72

# %%
data['Preis'] = [2.55 if i < 1
                 else 2.66 if (i>= 1) and (i< 2)
                 else 2.68 if (i>= 2) and (i< 3)
                else 2.72 if (i>= 3) and (i< 4)
                 else 2.77 if (i>= 4) and (i< 5)
                 else 2.85 if (i>=5) and (i< 6)
                 else 2.90 if (i>= 6) and (i<7)
                else 3.00 for i in data.PetalLengthCm]
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184
#
#         Ort  Anzahl  Preis  Zuechtung  Gewinn_pro_Stueck  Gewinne_pro_Verkauf
# 0       Ulm     172   2.66       1.03               1.52               1.5656
# 1     Trier     138   2.66       1.03               1.52               1.5656
# 2  Muenchen     144   2.66       1.03               1.52               1.5656
# 3   Rostock     210   2.66       1.03               1.52               1.5656
# 4   Hamburg      72   2.66       1.03               1.52               1.5656

# %%
data.groupby('Species').count()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Species
# Iris-setosa              11074         11091          11084         11085
# Iris-versicolor          11090         11090          11084         11080
# Iris-virginica           11094         11085          11083         11092
#
#                    Ort  Anzahl  Preis  Zuechtung  Gewinn_pro_Stueck  \
# Species
# Iris-setosa      11111   11111  11111      11111              11111
# Iris-versicolor  11111   11111  11111      11111              11111
# Iris-virginica   11111   11111  11111      11111              11111
#
#                  Gewinne_pro_Verkauf
# Species
# Iris-setosa                    11111
# Iris-versicolor                11111
# Iris-virginica                 11111

# %%
data['Zuechtung'] = [1.03 if i == 'Iris-setosa'
                   else 0.98 if i == 'Iris-versicolor'
                   else 1.55 for i in data.Species]
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184
#
#         Ort  Anzahl  Preis  Zuechtung  Gewinn_pro_Stueck  Gewinne_pro_Verkauf
# 0       Ulm     172   2.66       1.03               1.52               1.5656
# 1     Trier     138   2.66       1.03               1.52               1.5656
# 2  Muenchen     144   2.66       1.03               1.52               1.5656
# 3   Rostock     210   2.66       1.03               1.52               1.5656
# 4   Hamburg      72   2.66       1.03               1.52               1.5656

# %%
data['Gewinn_pro_Stueck'] = data.Preis - data.Zuechtung
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184
#
#         Ort  Anzahl  Preis  Zuechtung  Gewinn_pro_Stueck  Gewinne_pro_Verkauf
# 0       Ulm     172   2.66       1.03               1.63               1.5656
# 1     Trier     138   2.66       1.03               1.63               1.5656
# 2  Muenchen     144   2.66       1.03               1.63               1.5656
# 3   Rostock     210   2.66       1.03               1.63               1.5656
# 4   Hamburg      72   2.66       1.03               1.63               1.5656

# %%
data['Gewinne_pro_Verkauf'] = data.Gewinn_pro_Stueck * data.Zuechtung

# %%
data.head()
# Out:
#        Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  Iris-setosa       4.959947      3.210710       1.673597      0.248389
# 1  Iris-setosa       4.777595      3.131878       1.413592      0.113217
# 2  Iris-setosa       4.807163      3.475521       1.371495      0.159915
# 3  Iris-setosa       4.752104      3.738200       1.435881      0.234247
# 4  Iris-setosa       5.021368      2.382476       1.257389      0.198184
#
#         Ort  Anzahl  Preis  Zuechtung  Gewinn_pro_Stueck  Gewinne_pro_Verkauf
# 0       Ulm     172   2.66       1.03               1.63               1.6789
# 1     Trier     138   2.66       1.03               1.63               1.6789
# 2  Muenchen     144   2.66       1.03               1.63               1.6789
# 3   Rostock     210   2.66       1.03               1.63               1.6789
# 4   Hamburg      72   2.66       1.03               1.63               1.6789

# %%
# Gewinn je Species
data.groupby('Species').sum()['Gewinne_pro_Verkauf']
# Out:
# Species
# Iris-setosa        18660.3246
# Iris-versicolor    19390.5054
# Iris-virginica     22358.3625
# Name: Gewinne_pro_Verkauf, dtype: float64

# %%
data.columns
# Out:
# Index(['Species', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Ort', 'Anzahl', 'Preis', 'Zuechtung',
#        'Gewinn_pro_Stueck', 'Gewinne_pro_Verkauf'],
#       dtype='object')

# %%
data.groupby('Ort').sum()['Anzahl']
# Out:
# Ort
# Hamburg      506796
# Koeln        492766
# Leipzig      502898
# Muenchen     492659
# Muenster     509329
# Rostock      507916
# Trier        492364
# Ulm          497736
# Wolfsburg    503642
# Wuerzburg    490745
# Name: Anzahl, dtype: int64

# %% [markdown]
# * Betrachten Sie die Sepals und Petals der verschiedenen Iris Arten. Bestimmen Sie anhand von einem Plot, die Correlationen der Merkmale indem auch die verschiedenen Iris Arten sichtbar werden.
# * Gehen Sie nun davon aus, dass wir nur die Planze Iris ohne der Unterteilung der Arten Betrachten. Bei welchen Merkmalen erwarten Sie die größte Korrelation?
# * Überprüfen Sie Ihre Vermutung anhand einer Korrelationsmatrix. (also ohne Unterteilung der Arten)
# * Erstellen Sie ein Plot der diese Korrelationsmatrix visualisiert.

# %%
sb.pairplot(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
       'Species']], hue = 'Species')

# %%
sb.heatmap(data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm','Species']].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Welche Art wurde am meisten je Ort verkauft?
# * Visualisieren Sie den Gesamterlöse je Stadt.

# %%
temp = data.groupby(['Ort', 'Species']).sum()['Anzahl'].reset_index()
temp.groupby('Ort').max()
# Out:
#                   Species  Anzahl
# Ort
# Hamburg    Iris-virginica  172349
# Koeln      Iris-virginica  176075
# Leipzig    Iris-virginica  168419
# Muenchen   Iris-virginica  169350
# Muenster   Iris-virginica  171369
# Rostock    Iris-virginica  172741
# Trier      Iris-virginica  169915
# Ulm        Iris-virginica  177541
# Wolfsburg  Iris-virginica  174757
# Wuerzburg  Iris-virginica  167027

# %%
data.groupby('Ort').sum()['Gewinne_pro_Verkauf'].sort_values(ascending = False).plot(kind = 'bar');

# %% [markdown]
# * Geben Sie eine Vertriebsstrategie an: Welche Arten sollten in welcher Stadt mehr oder weniger angeboten werden, wenn der Gesamtgewinn betrachtet wird?

# %%
data.groupby(['Ort', 'Species']).sum()['Gewinne_pro_Verkauf'].unstack().plot(kind = 'bar', figsize=(15,5));
